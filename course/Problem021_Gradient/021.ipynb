# %% [markdown]
# <a href="https://colab.research.google.com/github/anna985/pml-1/blob/master/course/Problem021_Gradient/021.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Gradient or Slope or Rate of Change or Derivative
# ### $\begin{align} y' \text{ or } f'(x) \text{ or }  \frac{dy}{dx} \text{ or } \frac{d}{dx} f(x) \end{align}$

# %% [markdown]
# ## Derivative from first principles
#
# **TBD: ** Compute derivative of following functions from first principles
#
# $\begin{align}y = 5x\end{align}$
#
# $\begin{align}y = x^2\end{align}$

# %% [markdown]
# ## Simple Derivative Problems
# ** TBD**: Find derivatives for following functions
#
# $\begin{align}y = \sin(x)\end{align}$
#
# $\begin{align}y = x + 2\end{align}$
#
# $\begin{align}y = 5\sin(x)\end{align}$
#
# $\begin{align}y = 3x \end{align}$
#
# $\begin{align}y = 5\sin(x) + x^4 \end{align}$
#
# $\begin{align}y = 5x^4\sin(x) \end{align}$
#
# $\begin{align}y = 2e^x\log(x) \end{align}$

# %% [markdown]
# ![Screen Shot 2020-12-02 at 6.56.46 PM.png](data:image/png;base64,...)

# %% [markdown]
# ## Derivative from first principles
#
# **TBD: ** Compute derivative of following functions from first principles
#
# $\begin{align}y = x^2\end{align}$

# %% [markdown]
# ![Screen Shot 2020-12-02 at 6.35.34 PM.png](data:image/png;base64,...)
# ---

# %% [markdown]
# ## Derivative from first principles
#
# **TBD: ** Compute derivative of following functions from first principles
#
# $\begin{align}y = 10x\end{align}$

# %% [markdown]
# ![Screen Shot 2020-12-02 at 6.50.54 PM.png](data:image/png;base64,...)

# %% [markdown]
# ![Screen Shot 2020-12-02 at 7.00.25 PM.png](data:image/png;base64,...)
